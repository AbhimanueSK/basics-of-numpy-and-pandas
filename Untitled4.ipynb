# %%
import numpy as np

# %%
temperatures_w1 = np.array([22.5, 25.3, 20.8, 23.4, 26.1, 24.8, 21.9])

# %%
reshaped = temperatures_w1.reshape(-1, 1)
print(reshaped)
# Out:
# [[22.5]
#  [25.3]
#  [20.8]
#  [23.4]
#  [26.1]
#  [24.8]
#  [21.9]]

# %%
fahrenheit_w1 = (temperatures_w1 * 9/5) + 32
print(fahrenheit_w1)
# Out:
# [72.5  77.54 69.44 74.12 78.98 76.64 71.42]

# %%
mintemp=temperatures_w1.min()
print(mintemp)
# Out:
# 20.8

# %%
maxtemp=temperatures_w1.max()
print(maxtemp)
# Out:
# 26.1

# %%
meantemp=temperatures_w1.mean()
print(meantemp)
# Out:
# 23.542857142857144

# %%
print(temperatures_w1[1:3])
# Out:
# [25.3 20.8]

# %%
print(temperatures_w1[-2:])
# Out:
# [24.8 21.9]

# %%
print(temperatures_w1[3:5])
# Out:
# [23.4 26.1]

# %%
temperatures = np.array([
    [22.5, 25.3, 20.8, 23.4, 26.1, 24.8, 21.9],
    [19.2, 22.5, 21.3, 24.0, 23.5, 22.8, 20.1]])

# %%
temperatures.shape
# Out:
# (2, 7)

# %%
type(temperatures)
# Out:
# numpy.ndarray

# %%
temperatures.sum()
# Out:
# np.float64(318.20000000000005)

# %%
weekend_w1 = temperatures[0, -2:]

# %%
print("Weekend temperatures (Week 1):", weekend_w1)
# Out:
# Weekend temperatures (Week 1): [24.8 21.9]

# %%
weekend_w2 = temperatures[0, -2:]

# %%
print("Weekend temperatures (Week 2):", weekend_w2)
# Out:
# Weekend temperatures (Week 2): [24.8 21.9]

# %%
import pandas as pd

# %%
import pandas as pd
marks = pd.Series([95, 92, 89, 85, 80],index=['Rank1', 'Rank2', 'Rank3', 'Rank4', 'Rank5'])
print(marks)
# Out:
# Rank1    95
# Rank2    92
# Rank3    89
# Rank4    85
# Rank5    80
# dtype: int64

# %%
print("1st rank (by position):", mark[0])
# Out:
# 1st rank (by position): 95

# %%
print("Top 3 ranks (by label):")
print(mark,[['Rank1', 'Rank2', 'Rank3']])
# Out:
# Top 3 ranks (by label):
# [95 92 89 85 80] [['Rank1', 'Rank2', 'Rank3']]

# %%
print("3rd rank (by position):", mark[2])
# Out:
# 3rd rank (by position): 89

# %%
high_scores = mark[mark > 90]
print("Ranks with marks > 90:")
print(high_scores)
# Out:
# Ranks with marks > 90:
# [95 92]

# %%
mark ={}
mark['Rank1'] = 100

# %%
data = {'TransactionID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
        'ProductCategory': ['Electronics', 'Clothing', 'Electronics', 'Furniture','Clothing', 'Electronics', 'Furniture', 'Clothing','Furniture', 'Electronics'],
    'Region': ['North', 'South', 'North', 'East', 'West', 'North', 'East','West', 'South', 'North'],
    'Amount': [200, 150, 300, 450, 200, 250, 300, 180, 350, 400]}
transactions = pd.DataFrame(data)
print(transactions)
# Out:
#    TransactionID ProductCategory Region  Amount
# 0            101     Electronics  North     200
# 1            102        Clothing  South     150
# 2            103     Electronics  North     300
# 3            104       Furniture   East     450
# 4            105        Clothing   West     200
# 5            106     Electronics  North     250
# 6            107       Furniture   East     300
# 7            108        Clothing   West     180
# 8            109       Furniture  South     350
# 9            110     Electronics  North     400

# %%
print(transactions.head())     
print(transactions.tail())         
print("Shape:", transactions.shape)
print("Columns:", transactions.columns.tolist())
print("Data types:\n", transactions.dtypes)
# Out:
#    TransactionID ProductCategory Region  Amount
# 0            101     Electronics  North     200
# 1            102        Clothing  South     150
# 2            103     Electronics  North     300
# 3            104       Furniture   East     450
# 4            105        Clothing   West     200
#    TransactionID ProductCategory Region  Amount
# 5            106     Electronics  North     250
# 6            107       Furniture   East     300
# 7            108        Clothing   West     180
# 8            109       Furniture  South     350
# 9            110     Electronics  North     400
# Shape: (10, 4)
# Columns: ['TransactionID', 'ProductCategory', 'Region', 'Amount']
# Data types:
#  TransactionID       int64
# ProductCategory    object
# Region             object
# Amount              int64
# dtype: object

# %%
print(transactions[['ProductCategory', 'Amount']])
# Out:
#   ProductCategory  Amount
# 0     Electronics     200
# 1        Clothing     150
# 2     Electronics     300
# 3       Furniture     450
# 4        Clothing     200
# 5     Electronics     250
# 6       Furniture     300
# 7        Clothing     180
# 8       Furniture     350
# 9     Electronics     400

# %%
print(transactions.iloc[:, -3:])  # or use .loc[:, ['ProductCategory', 'Region', 'Amount']]
# Out:
#   ProductCategory Region  Amount
# 0     Electronics  North     200
# 1        Clothing  South     150
# 2     Electronics  North     300
# 3       Furniture   East     450
# 4        Clothing   West     200
# 5     Electronics  North     250
# 6       Furniture   East     300
# 7        Clothing   West     180
# 8       Furniture  South     350
# 9     Electronics  North     400

# %%
north_high = transactions[(transactions['Region'] == 'North') & (transactions['Amount'] > 200)]
print(north_high)
# Out:
#    TransactionID ProductCategory Region  Amount
# 2            103     Electronics  North     300
# 5            106     Electronics  North     250
# 9            110     Electronics  North     400

# %%
print(transactions['ProductCategory'].value_counts())
# Out:
# ProductCategory
# Electronics    4
# Clothing       3
# Furniture      3
# Name: count, dtype: int64

# %%
region_avg = transactions.groupby('Region')['Amount'].mean()
print(region_avg)
# Out:
# Region
# East     375.0
# North    287.5
# South    250.0
# West     190.0
# Name: Amount, dtype: float64

# %%
transactions = pd.DataFrame({'TransactionID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'ProductCategory': ['Electronics', 'Clothing', 'Electronics', 'Furniture','Clothing', 'Electronics', 'Furniture', 'Clothing','Furniture', 'Electronics'],
    'Region': ['North', 'South', 'North', 'East', 'West', 'North', 'East','West', 'South', 'North'],
    'Amount': [200, 150, 300, 450, 200, 250, 300, 180, 350, 400]})
transactions.loc[transactions['TransactionID'] == 102, 'Amount'] = 165
transactions['Discount'] = transactions['Amount'] * 0.10
transactions = transactions[transactions['TransactionID'] != 109]
transactions = transactions.drop(columns='Discount')
print(transactions)
# Out:
#    TransactionID ProductCategory Region  Amount
# 0            101     Electronics  North     200
# 1            102        Clothing  South     165
# 2            103     Electronics  North     300
# 3            104       Furniture   East     450
# 4            105        Clothing   West     200
# 5            106     Electronics  North     250
# 6            107       Furniture   East     300
# 7            108        Clothing   West     180
# 9            110     Electronics  North     400
